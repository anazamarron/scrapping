# %% [markdown]
# # Este notebook obtendrá los datos del tiempo y los guardará en Mongo

# %%
from lxml import html
import requests
import json
import pandas as pd
import pprint
import time

# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient()
client = MongoClient('localhost', 27017)

# %%
db = client.AEMET

# %%
collection = db['localidades']

# %%
resultado  = db.localidades.find({"nombe_localidad":"Guadiana del Caudillo"})
pp = pprint.PrettyPrinter(indent=1)
for doc in resultado:
    pp.pprint(doc)
# Out:
# {u'2015-06-17': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-06': u'N',
#                                        u'00-12': u'N',
#                                        u'00-24': u'N',
#                                        u'06-12': u'N',
#                                        u'12-18': u'N',
#                                        u'12-24': u'N',
#                                        u'18-24': u'NE'},
#                  u'estado_cielo': {u'00-06': u'Despejado',
#                                    u'00-12': u'Despejado',
#                                    u'00-24': u'Despejado',
#                                    u'06-12': u'Despejado',
#                                    u'12-18': u'Despejado',
#                                    u'12-24': u'Despejado',
#                                    u'18-24': u'Despejado'},
#                  u'humedad_relativa': {u'06': 75,
#                                        u'12': 35,
#                                        u'18': 25,
#                                        u'24': 55,
#                                        u'maxima': 80,
#                                        u'minima': 25},
#                  u'prob_precipitacion': {u'00-06': 0,
#                                          u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'06-12': 0,
#                                          u'12-18': 0,
#                                          u'12-24': 0,
#                                          u'18-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'06': 16,
#                                         u'12': 31,
#                                         u'18': 32,
#                                         u'24': 22,
#                                         u'maxima': 34,
#                                         u'minima': 15},
#                  u'temperatura': {u'06': 16,
#                                   u'12': 31,
#                                   u'18': 32,
#                                   u'24': 22,
#                                   u'maxima': 34,
#                                   u'minima': 15},
#                  u'uv_max': 8,
#                  u'velocidad_viento': {u'00-06': 5,
#                                        u'00-12': 5,
#                                        u'00-24': 5,
#                                        u'06-12': 5,
#                                        u'12-18': 10,
#                                        u'12-24': 10,
#                                        u'18-24': 5}},
#  u'2015-06-18': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-06': u'N',
#                                        u'00-12': u'N',
#                                        u'00-24': u'E',
#                                        u'06-12': u'E',
#                                        u'12-18': u'C',
#                                        u'12-24': u'E',
#                                        u'18-24': u'NE'},
#                  u'estado_cielo': {u'00-06': u'Despejado',
#                                    u'00-12': u'Despejado',
#                                    u'00-24': u'Despejado',
#                                    u'06-12': u'Despejado',
#                                    u'12-18': u'Despejado',
#                                    u'12-24': u'Despejado',
#                                    u'18-24': u'Despejado'},
#                  u'humedad_relativa': {u'06': 65,
#                                        u'12': 45,
#                                        u'18': 30,
#                                        u'24': 65,
#                                        u'maxima': 75,
#                                        u'minima': 30},
#                  u'prob_precipitacion': {u'00-06': 0,
#                                          u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'06-12': 0,
#                                          u'12-18': 0,
#                                          u'12-24': 0,
#                                          u'18-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'06': 18,
#                                         u'12': 29,
#                                         u'18': 32,
#                                         u'24': 20,
#                                         u'maxima': 33,
#                                         u'minima': 17},
#                  u'temperatura': {u'06': 18,
#                                   u'12': 29,
#                                   u'18': 32,
#                                   u'24': 20,
#                                   u'maxima': 33,
#                                   u'minima': 17},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-06': 5,
#                                        u'00-12': 5,
#                                        u'00-24': 5,
#                                        u'06-12': 5,
#                                        u'12-18': 0,
#                                        u'12-24': 5,
#                                        u'18-24': 5}},
#  u'2015-06-19': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-06': u'C',
#                                        u'00-12': u'E',
#                                        u'00-24': u'E',
#                                        u'06-12': u'E',
#                                        u'12-18': u'NE',
#                                        u'12-24': u'E',
#                                        u'18-24': u'N'},
#                  u'estado_cielo': {u'00-06': u'Despejado',
#                                    u'00-12': u'Despejado',
#                                    u'00-24': u'Despejado',
#                                    u'06-12': u'Despejado',
#                                    u'12-18': u'Despejado',
#                                    u'12-24': u'Despejado',
#                                    u'18-24': u'Despejado'},
#                  u'humedad_relativa': {u'06': 75,
#                                        u'12': 35,
#                                        u'18': 25,
#                                        u'24': 55,
#                                        u'maxima': 75,
#                                        u'minima': 25},
#                  u'prob_precipitacion': {u'00-06': 0,
#                                          u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'06-12': 0,
#                                          u'12-18': 0,
#                                          u'12-24': 0,
#                                          u'18-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'06': 19,
#                                         u'12': 32,
#                                         u'18': 34,
#                                         u'24': 21,
#                                         u'maxima': 35,
#                                         u'minima': 18},
#                  u'temperatura': {u'06': 19,
#                                   u'12': 32,
#                                   u'18': 34,
#                                   u'24': 21,
#                                   u'maxima': 35,
#                                   u'minima': 18},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-06': 0,
#                                        u'00-12': 10,
#                                        u'00-24': 10,
#                                        u'06-12': 10,
#                                        u'12-18': 10,
#                                        u'12-24': 10,
#                                        u'18-24': 5}},
#  u'2015-06-20': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-12': u'NE',
#                                        u'00-24': u'C',
#                                        u'12-24': u'C'},
#                  u'estado_cielo': {u'00-12': u'Despejado',
#                                    u'00-24': u'Despejado',
#                                    u'12-24': u'Poco nuboso'},
#                  u'humedad_relativa': {u'maxima': 55, u'minima': 20},
#                  u'prob_precipitacion': {u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'12-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 36, u'minima': 19},
#                  u'temperatura': {u'maxima': 36, u'minima': 19},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-12': 5, u'00-24': 0, u'12-24': 0}},
#  u'2015-06-21': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-12': u'SO',
#                                        u'00-24': u'O',
#                                        u'12-24': u'NO'},
#                  u'estado_cielo': {u'00-12': u'Poco nuboso',
#                                    u'00-24': u'Poco nuboso',
#                                    u'12-24': u'Poco nuboso'},
#                  u'humedad_relativa': {u'maxima': 60, u'minima': 25},
#                  u'prob_precipitacion': {u'00-12': 0,
#                                          u'00-24': 5,
#                                          u'12-24': 5},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 35, u'minima': 21},
#                  u'temperatura': {u'maxima': 35, u'minima': 21},
#                  u'uv_max': 8,
#                  u'velocidad_viento': {u'00-12': 10,
#                                        u'00-24': 5,
#                                        u'12-24': 5}},
#  u'2015-06-22': {u'cota_nieve': {},
#                  u'direccion_viento': {},
#                  u'estado_cielo': {},
#                  u'humedad_relativa': {u'maxima': 60, u'minima': 25},
#                  u'prob_precipitacion': {},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 34, u'minima': 21},
#                  u'temperatura': {u'maxima': 34, u'minima': 21},
#                  u'uv_max': 8,
#                  u'velocidad_viento': {}},
#  u'2015-06-23': {u'cota_nieve': {},
#                  u'direccion_viento': {},
#                  u'estado_cielo': {},
#                  u'humedad_relativa': {u'maxima': 60, u'minima': 20},
#                  u'prob_precipitacion': {},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 31, u'minima': 19},
#                  u'temperatura': {u'maxima': 31, u'minima': 19},
#                  u'velocidad_viento': {}},
#  u'2015-06-24': {u'cota_nieve': {},
#                  u'direccion_viento': {},
#                  u'estado_cielo': {},
#                  u'humedad_relativa': {u'maxima': 80, u'minima': 25},
#                  u'prob_precipitacion': {},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 30, u'minima': 15},
#                  u'temperatura': {u'maxima': 30, u'minima': 15},
#                  u'velocidad_viento': {}},
#  u'2015-06-30': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-06': u'C',
#                                        u'00-12': u'O',
#                                        u'00-24': u'O',
#                                        u'06-12': u'O',
#                                        u'12-18': u'O',
#                                        u'12-24': u'O',
#                                        u'18-24': u'O'},
#                  u'estado_cielo': {u'00-06': u'Despejado',
#                                    u'00-12': u'Despejado',
#                                    u'00-24': u'Despejado',
#                                    u'06-12': u'Despejado',
#                                    u'12-18': u'Despejado',
#                                    u'12-24': u'Despejado',
#                                    u'18-24': u'Despejado'},
#                  u'humedad_relativa': {u'06': 50,
#                                        u'12': 35,
#                                        u'18': 30,
#                                        u'24': 60,
#                                        u'maxima': 60,
#                                        u'minima': 30},
#                  u'prob_precipitacion': {u'00-06': 0,
#                                          u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'06-12': 0,
#                                          u'12-18': 0,
#                                          u'12-24': 0,
#                                          u'18-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'06': 24,
#                                         u'12': 36,
#                                         u'18': 35,
#                                         u'24': 25,
#                                         u'maxima': 38,
#                                         u'minima': 24},
#                  u'temperatura': {u'06': 24,
#                                   u'12': 36,
#                                   u'18': 35,
#                                   u'24': 25,
#                                   u'maxima': 38,
#                                   u'minima': 24},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-06': 0,
#                                        u'00-12': 5,
#                                        u'00-24': 5,
#                                        u'06-12': 5,
#                                        u'12-18': 15,
#                                        u'12-24': 15,
#                                        u'18-24': 10}},
#  u'2015-07-01': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-06': u'C',
#                                        u'00-12': u'O',
#                                        u'00-24': u'O',
#                                        u'06-12': u'O',
#                                        u'12-18': u'O',
#                                        u'12-24': u'O',
#                                        u'18-24': u'O'},
#                  u'estado_cielo': {u'00-06': u'Despejado',
#                                    u'00-12': u'Poco nuboso',
#                                    u'00-24': u'Nubes altas',
#                                    u'06-12': u'Poco nuboso',
#                                    u'12-18': u'Nubes altas',
#                                    u'12-24': u'Nubes altas',
#                                    u'18-24': u'Poco nuboso'},
#                  u'humedad_relativa': {u'06': 85,
#                                        u'12': 50,
#                                        u'18': 35,
#                                        u'24': 70,
#                                        u'maxima': 85,
#                                        u'minima': 35},
#                  u'prob_precipitacion': {u'00-06': 0,
#                                          u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'06-12': 0,
#                                          u'12-18': 0,
#                                          u'12-24': 0,
#                                          u'18-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'06': 18,
#                                         u'12': 29,
#                                         u'18': 30,
#                                         u'24': 21,
#                                         u'maxima': 31,
#                                         u'minima': 18},
#                  u'temperatura': {u'06': 18,
#                                   u'12': 28,
#                                   u'18': 30,
#                                   u'24': 21,
#                                   u'maxima': 31,
#                                   u'minima': 18},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-06': 0,
#                                        u'00-12': 10,
#                                        u'00-24': 10,
#                                        u'06-12': 10,
#                                        u'12-18': 15,
#                                        u'12-24': 15,
#                                        u'18-24': 10}},
#  u'2015-07-02': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-06': u'O',
#                                        u'00-12': u'O',
#                                        u'00-24': u'SO',
#                                        u'06-12': u'SO',
#                                        u'12-18': u'NO',
#                                        u'12-24': u'NO',
#                                        u'18-24': u'O'},
#                  u'estado_cielo': {u'00-06': u'Despejado',
#                                    u'00-12': u'Despejado',
#                                    u'00-24': u'Despejado',
#                                    u'06-12': u'Despejado',
#                                    u'12-18': u'Despejado',
#                                    u'12-24': u'Despejado',
#                                    u'18-24': u'Despejado'},
#                  u'humedad_relativa': {u'06': 85,
#                                        u'12': 35,
#                                        u'18': 20,
#                                        u'24': 50,
#                                        u'maxima': 85,
#                                        u'minima': 20},
#                  u'prob_precipitacion': {u'00-06': 0,
#                                          u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'06-12': 0,
#                                          u'12-18': 0,
#                                          u'12-24': 0,
#                                          u'18-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'06': 16,
#                                         u'12': 25,
#                                         u'18': 29,
#                                         u'24': 19,
#                                         u'maxima': 30,
#                                         u'minima': 16},
#                  u'temperatura': {u'06': 16,
#                                   u'12': 25,
#                                   u'18': 29,
#                                   u'24': 19,
#                                   u'maxima': 30,
#                                   u'minima': 16},
#                  u'uv_max': 8,
#                  u'velocidad_viento': {u'00-06': 10,
#                                        u'00-12': 10,
#                                        u'00-24': 5,
#                                        u'06-12': 5,
#                                        u'12-18': 10,
#                                        u'12-24': 10,
#                                        u'18-24': 10}},
#  u'2015-07-03': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-06': u'C',
#                                        u'00-12': u'O',
#                                        u'00-24': u'SO',
#                                        u'06-12': u'SO',
#                                        u'12-18': u'O',
#                                        u'12-24': u'O',
#                                        u'18-24': u'NO'},
#                  u'estado_cielo': {u'00-06': u'Despejado',
#                                    u'00-12': u'Despejado',
#                                    u'00-24': u'Despejado',
#                                    u'06-12': u'Despejado',
#                                    u'12-18': u'Despejado',
#                                    u'12-24': u'Despejado',
#                                    u'18-24': u'Despejado'},
#                  u'humedad_relativa': {u'06': 80,
#                                        u'12': 30,
#                                        u'18': 20,
#                                        u'24': 45,
#                                        u'maxima': 80,
#                                        u'minima': 20},
#                  u'prob_precipitacion': {u'00-06': 0,
#                                          u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'06-12': 0,
#                                          u'12-18': 0,
#                                          u'12-24': 0,
#                                          u'18-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'06': 16,
#                                         u'12': 29,
#                                         u'18': 32,
#                                         u'24': 21,
#                                         u'maxima': 33,
#                                         u'minima': 16},
#                  u'temperatura': {u'06': 16,
#                                   u'12': 29,
#                                   u'18': 32,
#                                   u'24': 21,
#                                   u'maxima': 33,
#                                   u'minima': 16},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-06': 0,
#                                        u'00-12': 10,
#                                        u'00-24': 5,
#                                        u'06-12': 5,
#                                        u'12-18': 15,
#                                        u'12-24': 15,
#                                        u'18-24': 10}},
#  u'2015-07-04': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-12': u'NO',
#                                        u'00-24': u'C',
#                                        u'12-24': u'O'},
#                  u'estado_cielo': {u'00-12': u'Despejado',
#                                    u'00-24': u'Despejado',
#                                    u'12-24': u'Despejado'},
#                  u'humedad_relativa': {u'maxima': 60, u'minima': 15},
#                  u'prob_precipitacion': {u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'12-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 35, u'minima': 18},
#                  u'temperatura': {u'maxima': 35, u'minima': 18},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-12': 10,
#                                        u'00-24': 0,
#                                        u'12-24': 10}},
#  u'2015-07-05': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-12': u'NO',
#                                        u'00-24': u'O',
#                                        u'12-24': u'NO'},
#                  u'estado_cielo': {u'00-12': u'Poco nuboso',
#                                    u'00-24': u'Nubes altas',
#                                    u'12-24': u'Nubes altas'},
#                  u'humedad_relativa': {u'maxima': 70, u'minima': 20},
#                  u'prob_precipitacion': {u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'12-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 37, u'minima': 21},
#                  u'temperatura': {u'maxima': 37, u'minima': 21},
#                  u'uv_max': 10,
#                  u'velocidad_viento': {u'00-12': 10,
#                                        u'00-24': 5,
#                                        u'12-24': 10}},
#  u'2015-07-06': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-06': u'C',
#                                        u'06-12': u'C',
#                                        u'12-18': u'O',
#                                        u'12-24': u'O',
#                                        u'18-24': u'NO'},
#                  u'estado_cielo': {u'00-06': u'',
#                                    u'00-12': u'',
#                                    u'00-24': u'',
#                                    u'06-12': u'Poco nuboso',
#                                    u'12-18': u'Poco nuboso',
#                                    u'12-24': u'Poco nuboso',
#                                    u'18-24': u'Poco nuboso'},
#                  u'humedad_relativa': {u'06': 65,
#                                        u'12': 30,
#                                        u'18': 25,
#                                        u'24': 50,
#                                        u'maxima': 70,
#                                        u'minima': 25},
#                  u'prob_precipitacion': {u'06-12': 0,
#                                          u'12-18': 0,
#                                          u'12-24': 0,
#                                          u'18-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'06': 20,
#                                         u'12': 36,
#                                         u'18': 38,
#                                         u'24': 26,
#                                         u'maxima': 40,
#                                         u'minima': 19},
#                  u'temperatura': {u'06': 20,
#                                   u'12': 36,
#                                   u'18': 38,
#                                   u'24': 26,
#                                   u'maxima': 40,
#                                   u'minima': 19},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-06': 0,
#                                        u'06-12': 0,
#                                        u'12-18': 15,
#                                        u'12-24': 15,
#                                        u'18-24': 5}},
#  u'2015-07-07': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-06': u'C',
#                                        u'00-12': u'NO',
#                                        u'00-24': u'C',
#                                        u'06-12': u'C',
#                                        u'12-18': u'NO',
#                                        u'12-24': u'NO',
#                                        u'18-24': u'NO'},
#                  u'estado_cielo': {u'00-06': u'Poco nuboso',
#                                    u'00-12': u'Despejado',
#                                    u'00-24': u'Despejado',
#                                    u'06-12': u'Despejado',
#                                    u'12-18': u'Despejado',
#                                    u'12-24': u'Despejado',
#                                    u'18-24': u'Poco nuboso'},
#                  u'humedad_relativa': {u'06': 70,
#                                        u'12': 30,
#                                        u'18': 15,
#                                        u'24': 45,
#                                        u'maxima': 75,
#                                        u'minima': 15},
#                  u'prob_precipitacion': {u'00-06': 0,
#                                          u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'06-12': 0,
#                                          u'12-18': 0,
#                                          u'12-24': 0,
#                                          u'18-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'06': 21,
#                                         u'12': 36,
#                                         u'18': 37,
#                                         u'24': 24,
#                                         u'maxima': 39,
#                                         u'minima': 20},
#                  u'temperatura': {u'06': 21,
#                                   u'12': 36,
#                                   u'18': 37,
#                                   u'24': 24,
#                                   u'maxima': 39,
#                                   u'minima': 20},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-06': 0,
#                                        u'00-12': 5,
#                                        u'00-24': 0,
#                                        u'06-12': 0,
#                                        u'12-18': 15,
#                                        u'12-24': 15,
#                                        u'18-24': 10}},
#  u'2015-07-08': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-12': u'NO',
#                                        u'00-24': u'C',
#                                        u'12-24': u'O'},
#                  u'estado_cielo': {u'00-12': u'Poco nuboso',
#                                    u'00-24': u'Poco nuboso',
#                                    u'12-24': u'Poco nuboso'},
#                  u'humedad_relativa': {u'maxima': 75, u'minima': 15},
#                  u'prob_precipitacion': {u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'12-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 38, u'minima': 19},
#                  u'temperatura': {u'maxima': 38, u'minima': 19},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-12': 10,
#                                        u'00-24': 0,
#                                        u'12-24': 10}},
#  u'2015-07-09': {u'cota_nieve': {},
#                  u'direccion_viento': {u'00-12': u'O',
#                                        u'00-24': u'SO',
#                                        u'12-24': u'O'},
#                  u'estado_cielo': {u'00-12': u'Despejado',
#                                    u'00-24': u'Despejado',
#                                    u'12-24': u'Despejado'},
#                  u'humedad_relativa': {u'maxima': 70, u'minima': 15},
#                  u'prob_precipitacion': {u'00-12': 0,
#                                          u'00-24': 0,
#                                          u'12-24': 0},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 39, u'minima': 21},
#                  u'temperatura': {u'maxima': 39, u'minima': 21},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {u'00-12': 5,
#                                        u'00-24': 5,
#                                        u'12-24': 15}},
#  u'2015-07-10': {u'cota_nieve': {},
#                  u'direccion_viento': {},
#                  u'estado_cielo': {},
#                  u'humedad_relativa': {u'maxima': 60, u'minima': 20},
#                  u'prob_precipitacion': {},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 36, u'minima': 21},
#                  u'temperatura': {u'maxima': 36, u'minima': 21},
#                  u'uv_max': 9,
#                  u'velocidad_viento': {}},
#  u'2015-07-11': {u'cota_nieve': {},
#                  u'direccion_viento': {},
#                  u'estado_cielo': {},
#                  u'humedad_relativa': {u'maxima': 80, u'minima': 20},
#                  u'prob_precipitacion': {},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 37, u'minima': 18},
#                  u'temperatura': {u'maxima': 37, u'minima': 18},
#                  u'velocidad_viento': {}},
#  u'2015-07-12': {u'cota_nieve': {},
#                  u'direccion_viento': {},
#                  u'estado_cielo': {},
#                  u'humedad_relativa': {u'maxima': 65, u'minima': 15},
#                  u'prob_precipitacion': {},
#                  u'racha_max': {},
#                  u'sensacion_termica': {u'maxima': 39, u'minima': 20},
#                  u'temperatura': {u'maxima': 39, u'minima': 20},
#                  u'velocidad_viento': {}},
#  u'_id': u'06903',
#  u'date': u'2015-06-17 07:53:46.146110',
#  u'id_localidad': u'guadiana-del-caudillo-id06903',
#  u'id_provincia': u'06',
#  u'nombe_localidad': u'Guadiana del Caudillo',
#  u'nombre_provincia': u'Badajoz'}

# %%
#Vamos a sacar los datos por localidades
# %timeit

for doc in db.localidades.find({}):
    
    url_prevision = "http://www.aemet.es/xml/municipios/localidad_" + doc['_id'] + ".xml"
    
    try:
        page_prevision = requests.get(url_prevision)
        tree_prevision = html.fromstring(page_prevision.content)
    except:
            print url_prevision

    for fecha in tree_prevision.xpath('//prediccion/dia/@fecha'):
    
        texto = '{"' + fecha + '": {'
    
        #Probabilidad de precipitacion
        hay = False
        texto += '"prob_precipitacion" : {' 
        for periodo in tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/prob_precipitacion/@periodo'):
            prob_precipitacion =  tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/prob_precipitacion[@periodo="'+periodo+'"]/text()')
            if prob_precipitacion:
                hay = True
                texto += ' "' + periodo + '": ' + prob_precipitacion[0] + ", "
        if hay:
            texto = texto[:-2]
        texto += "}"
            
        #Cota de nieve
        hay = False
        texto += ', "cota_nieve" : {' 
        for periodo in tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/cota_nieve/@periodo'):
            cota_nieve =  tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/cota_nieve[@periodo="'+periodo+'"]/text()')
            
            if cota_nieve:
                hay = True
                texto += ', "' + periodo + '": ' + cota_nieve[0] + ", "
        if hay:
            texto = texto[:-2]
        texto += "}"

        #Estado del cielo
        hay = False
        texto += ', "estado_cielo" : {' 
        for periodo in tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/estado_cielo/@periodo'):
            estado_cielo = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/estado_cielo[@periodo="'+periodo+'"]/@descripcion')                
            if estado_cielo:
                hay = True
                texto += '"' + periodo + '": "' + estado_cielo[0] + '", '
        if hay:
            texto = texto[:-2]
        texto += "}"

        #Direccion del viento
        hay = False
        texto += ', "direccion_viento" : {' 
        for periodo in tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/viento/@periodo'):
            direccion_viento = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/viento[@periodo="'+periodo+'"]/direccion/text()')
            if direccion_viento:
                hay=True
                texto += '"' + periodo + '": "' + direccion_viento[0] + '", '
        if hay:
            texto = texto[:-2]
        texto += "}"

            
        #Velocidad del viento
        hay = False
        texto += ', "velocidad_viento" : {' 
        for periodo in tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/viento/@periodo'):
            velocidad_viento = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/viento[@periodo="'+periodo+'"]/velocidad/text()')
            if velocidad_viento:
                hay = True
                texto += '"' + periodo + '": ' + velocidad_viento[0] + ", "
        if hay:
            texto = texto[:-2]
        texto += "}"            
           
            
        #Racha máxima
        hay = False
        texto += ', "racha_max" : {' 
        for periodo in tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/racha_max/@periodo'):
            racha_max =  tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/racha_max[@periodo="'+periodo+'"]/text()')
            if racha_max:
                hay = True
                texto += '"' + periodo + '": ' + racha_max[0] + ", "
        if hay:
            texto = texto[:-2]
        texto += "}"            

        #Temperatura
        
        texto += ', "temperatura" : {' 
        maxima = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/temperatura/maxima/text()') 
        texto += '"maxima":'+ maxima[0]+ ", "
        minima = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/temperatura/minima/text()')
        texto += '"minima":'+ minima[0] + ", "
        for hora in tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/temperatura/dato/@hora'):
            por_hora = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/temperatura/dato[@hora="'+hora+'"]/text()')
            if por_hora:
                texto += '"' + hora + '": '+ por_hora[0]+ ", "
        texto = texto[:-2]
        texto += "}"                    

        #Sensacion Termica
        texto += ', "sensacion_termica" : {' 
        maxima = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/sens_termica/maxima/text()') 
        texto += '"maxima":'+ maxima[0]+ ", "
        minima = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/sens_termica/minima/text()')
        texto += '"minima":'+ minima[0] + ", "
        for hora in tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/sens_termica/dato/@hora'):
            por_hora = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/sens_termica/dato[@hora="'+hora+'"]/text()') 
            if por_hora:
                texto += '"' + hora + '": '+ por_hora[0]+ ", "
        texto = texto[:-2]
        texto += "}"                    

        #Humedad relativa
        texto += ', "humedad_relativa" : {' 
        maxima = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/humedad_relativa/maxima/text()') 
        texto += '"maxima":'+ maxima[0]+ ", "
        minima = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/humedad_relativa/minima/text()')
        texto += '"minima":'+ minima[0] + ", "
        for hora in tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/humedad_relativa/dato/@hora'):
            por_hora = tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/humedad_relativa/dato[@hora="'+hora+'"]/text()') 
            if por_hora:
                texto += '"' + hora + '": '+ por_hora[0]+ ", "
        texto = texto[:-2]
        texto += "}"                    
        
        
        #UV max            
        uv_max =  tree_prevision.xpath('//prediccion/dia[@fecha="' + fecha + '"]/uv_max/text()')
        if uv_max:
            texto += ', "uv_max" : ' +  uv_max[0] 
            
        texto += '}}'

        json_acceptable_string = texto.replace('"', '\"')
        json_acceptable_string = texto.replace("'", "\"")
        
        d = json.loads(json_acceptable_string)

        post_id = collection.update({"_id" : doc["_id"]},{ "$set" : d}, upsert=True)

        time.sleep(0.01)

# %%
resultado  = db.localidades.find({"nombe_localidad":"Madrid"})
for doc in resultado:
    poblacion_temperatura = doc["2015-06-18"]["temperatura"]
    for element in poblacion_temperatura:
        print element , ', ' , poblacion_temperatura[element]
# Out:
# 24 ,  18
# minima ,  13
# 12 ,  25
# 06 ,  14
# 18 ,  27
# maxima ,  28

# %%
#db.drop_collection("localidades")
